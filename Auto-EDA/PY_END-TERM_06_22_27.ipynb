# %% [markdown]
# <h1 align='center'>PYTHON END TERM ASSIGNMENT</h1>
#
#
# <div style="float:right;">
#     <h3>Members :</h3>
#     <ol>
#     <li>Harshit Bardana (E21006)</li>
#     <li>Ujjwal Shekhar  (E21022)</li>
#     <li>Yash Kanakia    (E21027)</li>
#     </ol>
# </div>

# %%
# Importing Required packages

import os
import pandas as pd

# %% [markdown]
# <div style='width:auto;height:20px'><p style="background-color: #a3f8a3;color: #000000;border: 1px solid #3c763d;border-radius: 2px;text-align: center;font-size: 16px;font-weight: 600;">Loading the Dataset</p></div>

# %%
# Setting working directory

os.chdir(r"C:\Users\hp\Downloads")

# %%
# Reading the file

df=pd.read_csv("FuelConsumption.csv")
df.head(10)
# Out:
#    MODELYEAR   MAKE       MODEL VEHICLECLASS  ENGINESIZE  CYLINDERS  \
# 0       2014  ACURA         ILX      COMPACT         2.0          4
# 1       2014  ACURA         ILX      COMPACT         2.4          4
# 2       2014  ACURA  ILX HYBRID      COMPACT         1.5          4
# 3       2014  ACURA     MDX 4WD  SUV - SMALL         3.5          6
# 4       2014  ACURA     RDX AWD  SUV - SMALL         3.5          6
# 5       2014  ACURA         RLX     MID-SIZE         3.5          6
# 6       2014  ACURA          TL     MID-SIZE         3.5          6
# 7       2014  ACURA      TL AWD     MID-SIZE         3.7          6
# 8       2014  ACURA      TL AWD     MID-SIZE         3.7          6
# 9       2014  ACURA         TSX      COMPACT         2.4          4
#
#   TRANSMISSION FUELTYPE  FUELCONSUMPTION_CITY  FUELCONSUMPTION_HWY  \
# 0          AS5        Z                   9.9                  6.7
# 1           M6        Z                  11.2                  7.7
# ...

# %%
# Importing the EDA_Graph_Plot package that we created for plotting the graphs for required columns.

import EDA_Graph_Plot_V1_4 as eda

# %% [markdown]
# <h3 style="color:blue">Case 1</h3>

# %% [markdown]
# <div style='width:auto;height:20px'><p style="background-color: #a3f8a3;color: #000000;border: 1px solid #3c763d;border-radius: 2px;text-align: center;font-size: 16px;font-weight: 600;">Print the Graphs for all the columns in the Dataframe</p></div>

# %%
eda.Graphs(df)

# %% [markdown]
# <h3 style="color:blue">Case 2</h3>

# %% [markdown]
# <div style='width:auto;height:20px'><p style="background-color: #a3f8a3;color: #000000;border: 1px solid #3c763d;border-radius: 2px;text-align: center;font-size: 14px;font-weight: 600;">Print the Graphs for specified columns.<br>Numerical variable with unique values less than 10 would be plotted as Bar plot.</p></div><br>

# %%
eda.Graphs(df, variables=['ENGSIZE','MAKE','FUELCONSUMPTION_COMB','CO2EMISSIONS','TRANSMISSION'],
           directory='D:\\analytics\\Case2')

# %% [markdown]
# <h3 style="color:blue">Case 3</h3>

# %% [markdown]
# <div style='width:auto;height:20px'><p style="background-color: #a3f8a3;color: #000000;border: 1px solid #3c763d;border-radius: 2px;text-align: center;font-size: 14px;font-weight: 600;">Print the Graphs for coulumns excluding the ones specified by user.</p></div><br>

# %%
eda.Graphs(df, variables=['MODEL','MAKE','FUELCONSUMPTION_COMB','MODELYEAR'], directory='D:\\analytics\\Case3', drop=True)

# %% [markdown]
# <h3 style="color:blue">Case 4</h3>

# %% [markdown]
# <div style='width:auto;height:20px'><p style="background-color: #a3f8a3;color: #000000;border: 1px solid #3c763d;border-radius: 2px;text-align: center;font-size: 14px;font-weight: 600;">Print the Graphs with an option for the user to specify calegorical variables and/or Numerical variables.</p></div><br>

# %%
eda.Graphs(df, variables=['ENGINESIZE','CYLINDERS','FUELTYPE'],
           cat_var=['ENGINESIZE'],num_var='CYLINDERS', directory='D:\\analytics\\Case4')

# %% [markdown]
# <h3 style="color:blue">Case 5</h3>

# %% [markdown]
# <div style='width:auto;height:20px'><p style="background-color: #a3f8a3;color: #000000;border: 1px solid #3c763d;border-radius: 2px;text-align: center;font-size: 14px;font-weight: 600;">Exception Handling</p></div><br>

# %%
eda.Graphs(df, variables=['ENGINESIZE','MAKE','FUELCONSUMPTION_COMB','CO2EMISSIONS','TRANSMISSION','CYLINDERS'],
           cat_var=['ENGINESIZE'],num_var=['TRANSMISSION','MODEL'], directory='D:\\analytics\\Case5')
# Out:
# Specified Numerical variable is not present in entered variable set

# %%
eda.Graphs(df, variables=['ENGINESIZE','MAKE','FUELCONSUMPTION_COMB','CO2EMISSIONS','TRANSMISSION','CYLINDERS'],
           cat_var=['ENGINESIZE'],num_var=['TRANSMISSION','MODEL'], directory='D:\\analytics\\Case4',drop=True)
# Out:
# Specified Numerical variable is not present in entered variable set

# %%
eda.Graphs(df, variables=['ENGINESIZE','MAKE','FUELCONSUMPTION_COMB','CO2EMISSIONS','TRANSMISSION','CYLINDERS','MODEL'],
           cat_var=['ENGINESIZE'],num_var=['CYLINDERS','MODEL'], directory='D:\\analytics\\Case4')
# Out:
# String type cannot be used for box plot
